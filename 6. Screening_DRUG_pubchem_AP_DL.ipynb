# %%
## script save the model via h20
#model_path = h2o.save_model(model=dl_2, path="Output", force=True)
#print model_path

# %%
######################################################################

# %%
# 3. deep learning model
import pandas

import h2o
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 . connected.
# --------------------------  ------------------------------------------------------------------
# H2O_cluster_uptime:         2 hours 42 mins
# H2O_cluster_timezone:       Europe/London
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.30.1.3
# H2O_cluster_version_age:    1 month and 18 days
# H2O_cluster_name:           H2O_from_python_ISDADS_ezp715_3vyzr9
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    1.724 Gb
# H2O_cluster_total_cores:    4
# H2O_cluster_allowed_cores:  4
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://localhost:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# H2O_API_Extensions:         Amazon S3, XGBoost, Algos, AutoML, Core V3, TargetEncoder, Core V4
# Python_version:             2.7.18 final
# ...

# %%
## membaca file drug
drug = h2o.import_file("Output/fitur_drug_pubchem_ap_dl.csv", header=1)
drug.head()
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# <table>
# <thead>
# ...

# %%
#drug['label'] = '1'

# %%
#ganti tipe data
drug['idx_code'] = drug['idx_code'].ascharacter()
drug['chembl_code'] = drug['chembl_code'].ascharacter()
#drug['label'] = drug['label'].asfactor()

# %%
data_drug_X_dl = drug[:,3:884]
data_drug_X_dl.head()
# Out:
# <table>
# <thead>
# ...

# %%
dl_model = h2o.load_model("Output/DeepLearning_model_python_1605470869665_252")

# %%
pred = dl_model.predict(data_drug_X_dl[:-1]).as_data_frame(use_pandas=True)
# Out:
# deeplearning prediction progress: |███████████████████████████████████████| 100%

# %%
pred
# Out:
#     predict            p1            p0
# 0         1  1.000000e+00  1.673660e-29
# 1         0  8.139938e-16  1.000000e+00
# 2         1  1.000000e+00  4.637447e-35
# 3         0  1.011195e-06  9.999990e-01
# 4         0  2.305373e-07  9.999998e-01
# 5         1  9.990835e-01  9.165459e-04
# 6         0  3.385518e-28  1.000000e+00
# 7         1  1.000000e+00  2.333071e-13
# 8         1  1.000000e+00  1.289570e-33
# 9         1  1.000000e+00  2.579938e-24
# 10        1  1.000000e+00  2.579938e-24
# 11        0  6.046376e-04  9.993954e-01
# 12        0  6.046376e-04  9.993954e-01

# %%
pred['predict']
# Out:
# 0     1
# 1     0
# 2     1
# 3     0
# 4     0
# 5     1
# 6     0
# 7     1
# 8     1
# 9     1
# 10    1
# 11    0
# 12    0
# Name: predict, dtype: int64

# %%
#data_drug_X_dl.head()

# %%
#test_actual = data_drug_X_dl.as_data_frame(use_pandas=True)['label']

# %%
#test_actual

# %%
#(test_actual == pred['predict']).mean()

# %%
# ERROR
# 3. deep learning model
#membuka kembali model untuk digunakan dalam prediksi senyawa baru
#with open("Output/model_deeplearning_pubchem", "rb") as input_file:
#    model_baru_dl = pickle.load(input_file)

# %%
#menggunakan model tersimpan untuk prediksi
#y_drug_pred_dl = model_baru_dp.predict(data_drug_X)

# %%
#y_drug_pred_dl
